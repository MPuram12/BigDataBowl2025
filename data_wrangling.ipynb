# %%
import pandas as pd
import numpy as np

import process_data_functions as pdf

# %%
clean_data_1 = pdf.generate_clean_data(1)
#clean_data_1
#range(clean_data_1['angle_diff'])
'pass_result' in clean_data_1.columns
clean_data_1
# Out:
# Loading data for week 1...
# Input file: raw_data/input_2023_w01.csv
# Output file: raw_data/output_2023_w01.csv
# Supplementary file: supplementary_data.csv
# c:\Users\manik\Desktop\BigDataBowl\BigDataBowl2025\process_data_functions.py:293: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   supplementary_data = pd.read_csv(supplementary_path)
#           game_id  play_id  nfl_id  frame_id      x      y  ball_land_x  \
# 42     2023090700      101   44930         1  53.20  13.98    63.259998
# 43     2023090700      101   44930         2  53.96  13.78    63.259998
# 44     2023090700      101   44930         3  54.70  13.54    63.259998
# 45     2023090700      101   44930         4  55.41  13.27    63.259998
# 46     2023090700      101   44930         5  56.09  12.95    63.259998
# ...           ...      ...     ...       ...    ...    ...          ...
# 32072  2023091100     3987   46211         7  73.27  15.19    73.870003
# ...

# %%
print(clean_data_1['angle_diff'].describe())

#print(clean_data_1['optimal_angle'].describe())

print(clean_data_1['direction'].describe())

#'pass_result' in clean_data_1
# Out:
# count    32088.000000
# mean        53.639755
# std         47.737626
# min          0.000003
# 25%         15.769055
# 50%         37.413365
# 75%         80.099534
# max        179.990777
# Name: angle_diff, dtype: float64
# count    32088.000000
# mean        -2.812285
# std         99.788259
# min       -179.341457
# 25%        -88.619646
# 50%         -7.650651
# 75%         86.987212
# max        180.000000
# Name: direction, dtype: float64

# %%
for i in range(1, 19):
    clean_data = pdf.generate_clean_data(i)
    clean_data.to_csv('clean_data/week' + str(i) + '.csv')
# Out:
# Loading data for week 1...
# Input file: raw_data/input_2023_w01.csv
# Output file: raw_data/output_2023_w01.csv
# Supplementary file: supplementary_data.csv
# c:\Users\manik\Desktop\BigDataBowl\BigDataBowl2025\process_data_functions.py:293: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   supplementary_data = pd.read_csv(supplementary_path)
# Loading data for week 2...
# Input file: raw_data/input_2023_w02.csv
# Output file: raw_data/output_2023_w02.csv
# Supplementary file: supplementary_data.csv
# c:\Users\manik\Desktop\BigDataBowl\BigDataBowl2025\process_data_functions.py:293: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   supplementary_data = pd.read_csv(supplementary_path)
# Loading data for week 3...
# Input file: raw_data/input_2023_w03.csv
# Output file: raw_data/output_2023_w03.csv
# Supplementary file: supplementary_data.csv
# ...
