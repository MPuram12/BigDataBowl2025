# %%
import catch_probability_functions as cpf

# %%
cpf.load_all_last_frames().to_csv('final_frames.csv')
# Out:
# Starting to load data from directory: clean_data
# Loading clean_data\week1.csv...
# Found 2679 plays in week 1.
# Loading clean_data\week2.csv...
# Found 2758 plays in week 2.
# Loading clean_data\week3.csv...
# Found 2959 plays in week 3.
# Loading clean_data\week4.csv...
# Found 2517 plays in week 4.
# Loading clean_data\week5.csv...
# Found 2449 plays in week 5.
# Loading clean_data\week6.csv...
# Found 2608 plays in week 6.
# Loading clean_data\week7.csv...
# Found 2292 plays in week 7.
# Loading clean_data\week8.csv...
# Found 2705 plays in week 8.
# Loading clean_data\week9.csv...
# Found 2281 plays in week 9.
# Loading clean_data\week10.csv...
# Found 2365 plays in week 10.
# Loading clean_data\week11.csv...
# Found 2298 plays in week 11.
# Loading clean_data\week12.csv...
# Found 2705 plays in week 12.
# Loading clean_data\week13.csv...
# Found 2240 plays in week 13.
# Loading clean_data\week14.csv...
# Found 2611 plays in week 14.
# Loading clean_data\week15.csv...
# ...
